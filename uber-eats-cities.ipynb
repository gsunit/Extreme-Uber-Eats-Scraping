# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from urllib.request import Request, urlopen
from bs4 import BeautifulSoup
import re
  
URL = "https://www.ubereats.com/location"

req = Request(URL, headers={'User-Agent': 'Mozilla/5.0', 'Accept': 'text/html,application/xhtml+xml,application/xml'})
webpage = urlopen(req).read()
# print(webpage)
soup = BeautifulSoup(webpage, 'html.parser')

# %%
import pandas as pd
df = pd.DataFrame(columns=['city', 'state', 'url'])

# %%
states = soup.findAll("div", class_="av ax ay")
states = [state for state in states if state.text != "All Countries"]
len(states)

i = 0
for state in states:
    print(f"Processing: {state.text}")
    cities = state.parent.parent.findAll("a")
    for city in cities:
        df.loc[i] = [
            city.text,
            state.text,
            "https://www.ubereats.com" + city['href']
        ]
        i = i+1
# Out:
# 51
# Processing: Alabama
# Processing: Alaska
# Processing: Arizona
# Processing: Arkansas
# Processing: California
# Processing: Colorado
# Processing: Connecticut
# Processing: Delaware
# Processing: District Of Columbia
# Processing: Florida
# Processing: Georgia
# Processing: Hawaii
# Processing: Idaho
# Processing: Illinois
# Processing: Indiana
# Processing: Iowa
# Processing: Kansas
# Processing: Kentucky
# Processing: Louisiana
# Processing: Maine
# Processing: Maryland
# Processing: Massachusetts
# Processing: Michigan
# Processing: Minnesota
# Processing: Mississippi
# Processing: Missouri
# Processing: Montana
# Processing: Nebraska
# Processing: Nevada
# Processing: New Hampshire
# Processing: New Jersey
# Processing: New Mexico
# Processing: New York
# Processing: North Carolina
# Processing: North Dakota
# Processing: Ohio
# Processing: Oklahoma
# Processing: Oregon
# Processing: Pennsylvania
# Processing: Puerto Rico
# Processing: Rhode Island
# Processing: South Carolina
# Processing: South Dakota
# Processing: Tennessee
# Processing: Texas
# Processing: Utah
# Processing: Vermont
# Processing: Virginia
# Processing: West Virginia
# Processing: Wisconsin
# Processing: Wyoming

# %%
df.head(-1)
# Out:
#                    city      state  \
# 0                Auburn    Alabama
# 1        Birmingham, AL    Alabama
# 2                Dothan    Alabama
# 3              Homewood    Alabama
# 4                Hoover    Alabama
# 5            Huntsville    Alabama
# 6        Huntsville, AL    Alabama
# 7              Irondale    Alabama
# 8                Mobile    Alabama
# 9            Mobile, AL    Alabama
# 10       Montgomery, AL    Alabama
# 11            Northport    Alabama
# 12           Tuscaloosa    Alabama
# 13       Vestavia Hills    Alabama
# 14            Anchorage     Alaska
# 15      Apache Junction    Arizona
# 16             Avondale    Arizona
# 17             Chandler    Arizona
# 18            El Mirage    Arizona
# 19            Flagstaff    Arizona
# 20       Fountain Hills    Arizona
# 21              Gilbert    Arizona
# 22             Glendale    Arizona
# 23             Goodyear    Arizona
# 24            Guadalupe    Arizona
# 25     Lake Havasu City    Arizona
# 26       Laveen Village    Arizona
# 27       Laveen Village    Arizona
# 28      Litchfield Park    Arizona
# 29                 Mesa    Arizona
# ...                 ...        ...
# 3263           Kaukauna  Wisconsin
# 3264  Kenosha Wisconsin  Wisconsin
# 3265           Kimberly  Wisconsin
# 3266          La Crosse  Wisconsin
# 3267       Little Chute  Wisconsin
# 3268            Madison  Wisconsin
# 3269            Menasha  Wisconsin
# 3270    Menomonee Falls  Wisconsin
# 3271             Mequon  Wisconsin
# 3272          Middleton  Wisconsin
# 3273          Milwaukee  Wisconsin
# 3274             Monona  Wisconsin
# 3275             Neenah  Wisconsin
# 3276         New Berlin  Wisconsin
# 3277          Oak Creek  Wisconsin
# 3278            Oshkosh  Wisconsin
# 3279           Pewaukee  Wisconsin
# 3280             Racine  Wisconsin
# 3281      Saint Francis  Wisconsin
# 3282          Shorewood  Wisconsin
# 3283    South Milwaukee  Wisconsin
# 3284             Verona  Wisconsin
# 3285           Waukesha  Wisconsin
# 3286             Wausau  Wisconsin
# 3287          Wauwatosa  Wisconsin
# 3288         West Allis  Wisconsin
# 3289     West Milwaukee  Wisconsin
# 3290      Whitefish Bay  Wisconsin
# 3291    Wisconsin Dells  Wisconsin
# 3292             Casper    Wyoming
#
#                                                     url
# 0              https://www.ubereats.com/location/auburn
# 1       https://www.ubereats.com/location/birmingham-al
# 2              https://www.ubereats.com/location/dothan
# 3     https://www.ubereats.com/location/homewood-ala...
# 4      https://www.ubereats.com/location/hoover-alabama
# 5     https://www.ubereats.com/location/huntsville-a...
# 6       https://www.ubereats.com/location/huntsville-al
# 7     https://www.ubereats.com/location/irondale-ala...
# 8      https://www.ubereats.com/location/mobile-alabama
# 9           https://www.ubereats.com/location/mobile-al
# 10         https://www.ubereats.com/location/montgomery
# 11    https://www.ubereats.com/location/northport-al...
# 12         https://www.ubereats.com/location/tuscaloosa
# 13    https://www.ubereats.com/location/vestavia-hil...
# 14          https://www.ubereats.com/location/anchorage
# 15    https://www.ubereats.com/location/apache-junct...
# 16    https://www.ubereats.com/location/avondale-ari...
# 17    https://www.ubereats.com/location/chandler-ari...
# 18    https://www.ubereats.com/location/el-mirage-ar...
# 19          https://www.ubereats.com/location/flagstaff
# 20    https://www.ubereats.com/location/fountain-hil...
# 21    https://www.ubereats.com/location/gilbert-arizona
# 22    https://www.ubereats.com/location/glendale-ari...
# 23    https://www.ubereats.com/location/goodyear-ari...
# 24    https://www.ubereats.com/location/guadalupe-ar...
# 25    https://www.ubereats.com/location/lake-havasu-...
# 26    https://www.ubereats.com/location/laveen-villa...
# 27     https://www.ubereats.com/location/laveen-arizona
# 28    https://www.ubereats.com/location/litchfield-p...
# 29       https://www.ubereats.com/location/mesa-arizona
# ...                                                 ...
# 3263  https://www.ubereats.com/location/kaukauna-wis...
# 3264  https://www.ubereats.com/location/kenosha-wisc...
# 3265  https://www.ubereats.com/location/kimberly-wis...
# 3266        https://www.ubereats.com/location/la-crosse
# 3267  https://www.ubereats.com/location/little-chute...
# 3268          https://www.ubereats.com/location/madison
# 3269  https://www.ubereats.com/location/menasha-wisc...
# 3270  https://www.ubereats.com/location/menomonee-fa...
# 3271  https://www.ubereats.com/location/mequon-wisco...
# 3272  https://www.ubereats.com/location/middleton-wi...
# 3273        https://www.ubereats.com/location/milwaukee
# 3274  https://www.ubereats.com/location/monona-wisco...
# 3275  https://www.ubereats.com/location/neenah-wisco...
# 3276  https://www.ubereats.com/location/new-berlin-w...
# 3277  https://www.ubereats.com/location/oak-creek-wi...
# 3278  https://www.ubereats.com/location/oshkosh-wisc...
# 3279  https://www.ubereats.com/location/pewaukee-wis...
# 3280  https://www.ubereats.com/location/racine-wisco...
# 3281  https://www.ubereats.com/location/st-francis-w...
# 3282  https://www.ubereats.com/location/shorewood-wi...
# 3283  https://www.ubereats.com/location/south-milwau...
# 3284  https://www.ubereats.com/location/verona-wisco...
# 3285  https://www.ubereats.com/location/waukesha-wis...
# 3286  https://www.ubereats.com/location/wausau-wisco...
# 3287  https://www.ubereats.com/location/wauwatosa-wi...
# 3288  https://www.ubereats.com/location/west-allis-w...
# 3289  https://www.ubereats.com/location/west-milwauk...
# 3290  https://www.ubereats.com/location/whitefish-ba...
# 3291  https://www.ubereats.com/location/wisconsin-de...
# 3292   https://www.ubereats.com/location/casper-wyoming
#
# [3293 rows x 3 columns]

# %%
df.to_csv("uber-eats-cities.csv", index=None)

# %%
for i in range(0,10):
    cities[i].parent.parent.name
# Out:
# 'div'
# 'div'
# 'div'
# 'div'
# 'div'
# 'div'
# 'div'
# 'div'
# 'div'
# 'div'
